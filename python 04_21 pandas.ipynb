# %%
import pandas as pd

# %%
import numpy as np

# %%
train = pd.read_csv("data/train.csv", index_col="PassengerId")

print(train.shape)
train.head()
# Out:
# (891, 15)
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 1                   0       3           0   NaN    male           0      0
# 2                   1       1           1   C85  female           1      0
# 3                   1       3           1   NaN  female           1      0
# 4                   1       1           1  C123  female           1      0
# 5                   0       3           0   NaN    male           0      0
#
#               Age  Survived.3  SibSp  Parch  Family            Ticket  \
# PassengerId
# 1            22.0           0      1      0       1         A/5 21171
# 2            38.0           1      1      0       1          PC 17599
# 3            26.0           1      0      0       0  STON/O2. 3101282
# 4            35.0           1      1      0       1            113803
# 5            35.0           0      0      0       0            373450
#
#                 Fare Embarked
# PassengerId
# 1             7.2500        S
# 2            71.2833        C
# 3             7.9250        S
# 4            53.1000        S
# 5             8.0500        S

# %%
pwd
# Out:
# 'C:\\Users\\elee0'

# %% [markdown]
# ## 행렬 검색

# %%
train["Survived"].head()
# Out:
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %%
train[["Sex", "Survived"]].head()
# Out:
#                 Sex  Survived
# PassengerId
# 1              male         0
# 2            female         1
# 3            female         1
# 4            female         1
# 5              male         0

# %%
train.loc[1]
# Out:
# Survived              0
# Pclass                3
# Survived.1            0
# Cabin               NaN
# Sex                male
# Survived.2            0
# Child                 0
# Age                  22
# Survived.3            0
# SibSp                 1
# Parch                 0
# Family                1
# Ticket        A/5 21171
# Fare               7.25
# Embarked              S
# Name: 1, dtype: object

# %%
train.loc[[1, 3, 5]]
passenger_ids = [1, 3, 5, 7]
train.loc[passenger_ids]
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 1                   0       3           0   NaN    male           0      0
# 3                   1       3           1   NaN  female           1      0
# 5                   0       3           0   NaN    male           0      0
# 7                   0       1           0   E46    male           0      0
#
#               Age  Survived.3  SibSp  Parch  Family            Ticket  \
# PassengerId
# 1            22.0           0      1      0       1         A/5 21171
# 3            26.0           1      0      0       0  STON/O2. 3101282
# 5            35.0           0      0      0       0            373450
# 7            54.0           0      0      0       0             17463
#
#                 Fare Embarked
# PassengerId
# 1             7.2500        S
# 3             7.9250        S
# 5             8.0500        S
# 7            51.8625        S

# %%
train.loc[1, ["Sex", "Survived"]]
# Out:
# Sex         male
# Survived       0
# Name: 1, dtype: object

# %%
train[train["Sex"] == "male"]
# Out:
#              Survived  Pclass  Survived.1        Cabin   Sex  Survived.2  \
# PassengerId
# 1                   0       3           0          NaN  male           0
# 5                   0       3           0          NaN  male           0
# 6                   0       3           0          NaN  male           0
# 7                   0       1           0          E46  male           0
# 8                   0       3           0          NaN  male           0
# 13                  0       3           0          NaN  male           0
# 14                  0       3           0          NaN  male           0
# 17                  0       3           0          NaN  male           0
# 18                  1       2           1          NaN  male           1
# 21                  0       2           0          NaN  male           0
# 22                  1       2           1          D56  male           1
# 24                  1       1           1           A6  male           1
# 27                  0       3           0          NaN  male           0
# 28                  0       1           0  C23 C25 C27  male           0
# 30                  0       3           0          NaN  male           0
# 31                  0       1           0          NaN  male           0
# 34                  0       2           0          NaN  male           0
# 35                  0       1           0          NaN  male           0
# 36                  0       1           0          NaN  male           0
# 37                  1       3           1          NaN  male           1
# 38                  0       3           0          NaN  male           0
# 43                  0       3           0          NaN  male           0
# 46                  0       3           0          NaN  male           0
# 47                  0       3           0          NaN  male           0
# 49                  0       3           0          NaN  male           0
# 51                  0       3           0          NaN  male           0
# 52                  0       3           0          NaN  male           0
# 55                  0       1           0          B30  male           0
# 56                  1       1           1          C52  male           1
# 58                  0       3           0          NaN  male           0
# ...               ...     ...         ...          ...   ...         ...
# 841                 0       3           0          NaN  male           0
# 842                 0       2           0          NaN  male           0
# 844                 0       3           0          NaN  male           0
# 845                 0       3           0          NaN  male           0
# 846                 0       3           0          NaN  male           0
# 847                 0       3           0          NaN  male           0
# 848                 0       3           0          NaN  male           0
# 849                 0       2           0          NaN  male           0
# 851                 0       3           0          NaN  male           0
# 852                 0       3           0          NaN  male           0
# 858                 1       1           1          E17  male           1
# 860                 0       3           0          NaN  male           0
# 861                 0       3           0          NaN  male           0
# 862                 0       2           0          NaN  male           0
# 865                 0       2           0          NaN  male           0
# 868                 0       1           0          A24  male           0
# 869                 0       3           0          NaN  male           0
# 870                 1       3           1          NaN  male           1
# 871                 0       3           0          NaN  male           0
# 873                 0       1           0  B51 B53 B55  male           0
# 874                 0       3           0          NaN  male           0
# 877                 0       3           0          NaN  male           0
# 878                 0       3           0          NaN  male           0
# 879                 0       3           0          NaN  male           0
# 882                 0       3           0          NaN  male           0
# 884                 0       2           0          NaN  male           0
# 885                 0       3           0          NaN  male           0
# 887                 0       2           0          NaN  male           0
# 890                 1       1           1         C148  male           1
# 891                 0       3           0          NaN  male           0
#
#              Child   Age  Survived.3  SibSp  Parch  Family            Ticket  \
# PassengerId
# 1                0  22.0           0      1      0       1         A/5 21171
# 5                0  35.0           0      0      0       0            373450
# 6                0   NaN           0      0      0       0            330877
# 7                0  54.0           0      0      0       0             17463
# 8                1   2.0           0      3      1       4            349909
# 13               0  20.0           0      0      0       0         A/5. 2151
# 14               0  39.0           0      1      5       6            347082
# 17               1   2.0           0      4      1       5            382652
# 18               0   NaN           1      0      0       0            244373
# 21               0  35.0           0      0      0       0            239865
# 22               0  34.0           1      0      0       0            248698
# 24               0  28.0           1      0      0       0            113788
# 27               0   NaN           0      0      0       0              2631
# 28               0  19.0           0      3      2       5             19950
# 30               0   NaN           0      0      0       0            349216
# 31               0  40.0           0      0      0       0          PC 17601
# 34               0  66.0           0      0      0       0        C.A. 24579
# 35               0  28.0           0      1      0       1          PC 17604
# 36               0  42.0           0      1      0       1            113789
# 37               0   NaN           1      0      0       0              2677
# 38               0  21.0           0      0      0       0        A./5. 2152
# 43               0   NaN           0      0      0       0            349253
# 46               0   NaN           0      0      0       0   S.C./A.4. 23567
# 47               0   NaN           0      1      0       1            370371
# 49               0   NaN           0      2      0       2              2662
# 51               1   7.0           0      4      1       5           3101295
# 52               0  21.0           0      0      0       0        A/4. 39886
# 55               0  65.0           0      0      1       1            113509
# 56               0   NaN           1      0      0       0             19947
# 58               0  28.5           0      0      0       0              2697
# ...            ...   ...         ...    ...    ...     ...               ...
# 841              0  20.0           0      0      0       0  SOTON/O2 3101287
# 842              1  16.0           0      0      0       0       S.O./P.P. 3
# 844              0  34.5           0      0      0       0              2683
# 845              1  17.0           0      0      0       0            315090
# 846              0  42.0           0      0      0       0         C.A. 5547
# 847              0   NaN           0      8      2      10          CA. 2343
# 848              0  35.0           0      0      0       0            349213
# 849              0  28.0           0      0      1       1            248727
# 851              1   4.0           0      4      2       6            347082
# 852              0  74.0           0      0      0       0            347060
# 858              0  51.0           1      0      0       0            113055
# 860              0   NaN           0      0      0       0              2629
# 861              0  41.0           0      2      0       2            350026
# 862              0  21.0           0      1      0       1             28134
# 865              0  24.0           0      0      0       0            233866
# 868              0  31.0           0      0      0       0          PC 17590
# 869              0   NaN           0      0      0       0            345777
# 870              1   4.0           1      1      1       2            347742
# 871              0  26.0           0      0      0       0            349248
# 873              0  33.0           0      0      0       0               695
# 874              0  47.0           0      0      0       0            345765
# 877              0  20.0           0      0      0       0              7534
# 878              0  19.0           0      0      0       0            349212
# 879              0   NaN           0      0      0       0            349217
# 882              0  33.0           0      0      0       0            349257
# 884              0  28.0           0      0      0       0  C.A./SOTON 34068
# 885              0  25.0           0      0      0       0   SOTON/OQ 392076
# 887              0  27.0           0      0      0       0            211536
# 890              0  26.0           1      0      0       0            111369
# 891              0  32.0           0      0      0       0            370376
#
#                  Fare Embarked
# PassengerId
# 1              7.2500        S
# 5              8.0500        S
# 6              8.4583        Q
# 7             51.8625        S
# 8             21.0750        S
# 13             8.0500        S
# 14            31.2750        S
# 17            29.1250        Q
# 18            13.0000        S
# 21            26.0000        S
# 22            13.0000        S
# 24            35.5000        S
# 27             7.2250        C
# 28           263.0000        S
# 30             7.8958        S
# 31            27.7208        C
# 34            10.5000        S
# 35            82.1708        C
# 36            52.0000        S
# 37             7.2292        C
# 38             8.0500        S
# 43             7.8958        C
# 46             8.0500        S
# 47            15.5000        Q
# 49            21.6792        C
# 51            39.6875        S
# 52             7.8000        S
# 55            61.9792        C
# 56            35.5000        S
# 58             7.2292        C
# ...               ...      ...
# 841            7.9250        S
# 842           10.5000        S
# 844            6.4375        C
# 845            8.6625        S
# 846            7.5500        S
# 847           69.5500        S
# 848            7.8958        C
# 849           33.0000        S
# 851           31.2750        S
# 852            7.7750        S
# 858           26.5500        S
# 860            7.2292        C
# 861           14.1083        S
# 862           11.5000        S
# 865           13.0000        S
# 868           50.4958        S
# 869            9.5000        S
# 870           11.1333        S
# 871            7.8958        S
# 873            5.0000        S
# 874            9.0000        S
# 877            9.8458        S
# 878            7.8958        S
# 879            7.8958        S
# 882            7.8958        S
# 884           10.5000        S
# 885            7.0500        S
# 887           13.0000        S
# 890           30.0000        C
# 891            7.7500        Q
#
# [577 rows x 15 columns]

# %%
train[train["Fare"] > 20].head()
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 2                   1       1           1   C85  female           1      0
# 4                   1       1           1  C123  female           1      0
# 7                   0       1           0   E46    male           0      0
# 8                   0       3           0   NaN    male           0      1
# 10                  1       2           1   NaN  female           1      1
#
#               Age  Survived.3  SibSp  Parch  Family    Ticket     Fare  \
# PassengerId
# 2            38.0           1      1      0       1  PC 17599  71.2833
# 4            35.0           1      1      0       1    113803  53.1000
# 7            54.0           0      0      0       0     17463  51.8625
# 8             2.0           0      3      1       4    349909  21.0750
# 10           14.0           1      1      0       1    237736  30.0708
#
#             Embarked
# PassengerId
# 2                  C
# 4                  S
# 7                  S
# 8                  S
# 10                 C

# %%
train[train["Embarked"] == "C"].head()
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 2                   1       1           1   C85  female           1      0
# 10                  1       2           1   NaN  female           1      1
# 20                  1       3           1   NaN  female           1      0
# 27                  0       3           0   NaN    male           0      0
# 31                  0       1           0   NaN    male           0      0
#
#               Age  Survived.3  SibSp  Parch  Family    Ticket     Fare  \
# PassengerId
# 2            38.0           1      1      0       1  PC 17599  71.2833
# 10           14.0           1      1      0       1    237736  30.0708
# 20            NaN           1      0      0       0      2649   7.2250
# 27            NaN           0      0      0       0      2631   7.2250
# 31           40.0           0      0      0       0  PC 17601  27.7208
#
#             Embarked
# PassengerId
# 2                  C
# 10                 C
# 20                 C
# 27                 C
# 31                 C

# %%
train[train["Embarked"] != "C"].head()
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 1                   0       3           0   NaN    male           0      0
# 3                   1       3           1   NaN  female           1      0
# 4                   1       1           1  C123  female           1      0
# 5                   0       3           0   NaN    male           0      0
# 6                   0       3           0   NaN    male           0      0
#
#               Age  Survived.3  SibSp  Parch  Family            Ticket  \
# PassengerId
# 1            22.0           0      1      0       1         A/5 21171
# 3            26.0           1      0      0       0  STON/O2. 3101282
# 4            35.0           1      1      0       1            113803
# 5            35.0           0      0      0       0            373450
# 6             NaN           0      0      0       0            330877
#
#                 Fare Embarked
# PassengerId
# 1             7.2500        S
# 3             7.9250        S
# 4            53.1000        S
# 5             8.0500        S
# 6             8.4583        Q

# %%
train[train["Age"].isnull()].head()
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 6                   0       3           0   NaN    male           0      0
# 18                  1       2           1   NaN    male           1      0
# 20                  1       3           1   NaN  female           1      0
# 27                  0       3           0   NaN    male           0      0
# 29                  1       3           1   NaN  female           1      0
#
#              Age  Survived.3  SibSp  Parch  Family  Ticket     Fare Embarked
# PassengerId
# 6            NaN           0      0      0       0  330877   8.4583        Q
# 18           NaN           1      0      0       0  244373  13.0000        S
# 20           NaN           1      0      0       0    2649   7.2250        C
# 27           NaN           0      0      0       0    2631   7.2250        C
# 29           NaN           1      0      0       0  330959   7.8792        Q

# %%
train[train["Age"].notnull()].head()
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 1                   0       3           0   NaN    male           0      0
# 2                   1       1           1   C85  female           1      0
# 3                   1       3           1   NaN  female           1      0
# 4                   1       1           1  C123  female           1      0
# 5                   0       3           0   NaN    male           0      0
#
#               Age  Survived.3  SibSp  Parch  Family            Ticket  \
# PassengerId
# 1            22.0           0      1      0       1         A/5 21171
# 2            38.0           1      1      0       1          PC 17599
# 3            26.0           1      0      0       0  STON/O2. 3101282
# 4            35.0           1      1      0       1            113803
# 5            35.0           0      0      0       0            373450
#
#                 Fare Embarked
# PassengerId
# 1             7.2500        S
# 2            71.2833        C
# 3             7.9250        S
# 4            53.1000        S
# 5             8.0500        S

# %%
null_age = train["Age"].isnull()
null_fare = train["Fare"].isnull()

train[null_age | null_fare].head()
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 6                   0       3           0   NaN    male           0      0
# 18                  1       2           1   NaN    male           1      0
# 20                  1       3           1   NaN  female           1      0
# 27                  0       3           0   NaN    male           0      0
# 29                  1       3           1   NaN  female           1      0
#
#              Age  Survived.3  SibSp  Parch  Family  Ticket     Fare Embarked
# PassengerId
# 6            NaN           0      0      0       0  330877   8.4583        Q
# 18           NaN           1      0      0       0  244373  13.0000        S
# 20           NaN           1      0      0       0    2649   7.2250        C
# 27           NaN           0      0      0       0    2631   7.2250        C
# 29           NaN           1      0      0       0  330959   7.8792        Q

# %% [markdown]
# ## 기본연산

# %% [raw]
# train["Fare"].mean()

# %%
train["Fare"].mean()
# Out:
# 32.2042079685746

# %%
train["Age"].max()
# Out:
# 80.0

# %%
train["Age"].min()
# Out:
# 0.42

# %% [markdown]
# ## 컬럼 수정하기 추가하기

# %%
train["Category"] = "Titanic"
train.head()
train.shape
# Out:
# (891, 16)

# %%
train["Id"] = range(891)
train.head()
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 1                   0       3           0   NaN    male           0      0
# 2                   1       1           1   C85  female           1      0
# 3                   1       3           1   NaN  female           1      0
# 4                   1       1           1  C123  female           1      0
# 5                   0       3           0   NaN    male           0      0
#
#               Age  Survived.3  SibSp  Parch  Family            Ticket  \
# PassengerId
# 1            22.0           0      1      0       1         A/5 21171
# 2            38.0           1      1      0       1          PC 17599
# 3            26.0           1      0      0       0  STON/O2. 3101282
# 4            35.0           1      1      0       1            113803
# 5            35.0           0      0      0       0            373450
#
#                 Fare Embarked Category  Id
# PassengerId
# 1             7.2500        S  Titanic   0
# 2            71.2833        C  Titanic   1
# 3             7.9250        S  Titanic   2
# 4            53.1000        S  Titanic   3
# 5             8.0500        S  Titanic   4

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
train[["SibSp", "Parch", "FamilySize"]].head()
# Out:
#              SibSp  Parch  FamilySize
# PassengerId
# 1                1      0           2
# 2                1      0           2
# 3                0      0           1
# 4                1      0           2
# 5                0      0           1

# %%
train["Nationality_FR"] = train["Embarked"] == "C"
train["Nationality_UK"] = train["Embarked"] != "C"
train[["Embarked", "Nationality_FR", "Nationality_UK"]].head()
# Out:
#             Embarked  Nationality_FR  Nationality_UK
# PassengerId
# 1                  S           False            True
# 2                  C            True           False
# 3                  S           False            True
# 4                  S           False            True
# 5                  S           False            True

# %%
train.loc[train["Embarked"] == "C", "Nationality"] = "France"
train.loc[train["Embarked"] != "C", "Nationality"] = "England"
train.head()
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 1                   0       3           0   NaN    male           0      0
# 2                   1       1           1   C85  female           1      0
# 3                   1       3           1   NaN  female           1      0
# 4                   1       1           1  C123  female           1      0
# 5                   0       3           0   NaN    male           0      0
#
#               Age  Survived.3  SibSp     ...       Family            Ticket  \
# PassengerId                              ...
# 1            22.0           0      1     ...            1         A/5 21171
# 2            38.0           1      1     ...            1          PC 17599
# 3            26.0           1      0     ...            0  STON/O2. 3101282
# 4            35.0           1      1     ...            1            113803
# 5            35.0           0      0     ...            0            373450
#
#                 Fare  Embarked Category Id  FamilySize  Nationality_FR  \
# PassengerId
# 1             7.2500         S  Titanic  0           2           False
# 2            71.2833         C  Titanic  1           2            True
# 3             7.9250         S  Titanic  2           1           False
# 4            53.1000         S  Titanic  3           2           False
# 5             8.0500         S  Titanic  4           1           False
#
#              Nationality_UK  Nationality
# PassengerId
# 1                      True      England
# 2                     False       France
# 3                      True      England
# 4                      True      England
# 5                      True      England
#
# [5 rows x 21 columns]

# %%
mean_age = train["Age"].mean()

train.loc[train["Age"].isnull(), "Age"] = mean_age

train.head()
# Out:
#              Survived  Pclass  Survived.1 Cabin     Sex  Survived.2  Child  \
# PassengerId
# 1                   0       3           0   NaN    male           0      0
# 2                   1       1           1   C85  female           1      0
# 3                   1       3           1   NaN  female           1      0
# 4                   1       1           1  C123  female           1      0
# 5                   0       3           0   NaN    male           0      0
#
#               Age  Survived.3  SibSp     ...       Family            Ticket  \
# PassengerId                              ...
# 1            22.0           0      1     ...            1         A/5 21171
# 2            38.0           1      1     ...            1          PC 17599
# 3            26.0           1      0     ...            0  STON/O2. 3101282
# 4            35.0           1      1     ...            1            113803
# 5            35.0           0      0     ...            0            373450
#
#                 Fare  Embarked Category Id  FamilySize  Nationality_FR  \
# PassengerId
# 1             7.2500         S  Titanic  0           2           False
# 2            71.2833         C  Titanic  1           2            True
# 3             7.9250         S  Titanic  2           1           False
# 4            53.1000         S  Titanic  3           2           False
# 5             8.0500         S  Titanic  4           1           False
#
#              Nationality_UK  Nationality
# PassengerId
# 1                      True      England
# 2                     False       France
# 3                      True      England
# 4                      True      England
# 5                      True      England
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 저장하기

# %%
train.to_csv("data/train_modified.csv")
