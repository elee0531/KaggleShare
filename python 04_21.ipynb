# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
pwd
# Out:
# 'C:\\Users\\elee0'

# %%
# Out:
# 'C:\\Users\\elee0'

# %%
# Out:
# 'C:\\Users\\elee0'

# %%
pd.read_csv("data/train.csv")
# Out:
#      PassengerId  Survived  Pclass  Survived.1        Cabin     Sex  \
# 0              1         0       3           0          NaN    male
# 1              2         1       1           1          C85  female
# 2              3         1       3           1          NaN  female
# 3              4         1       1           1         C123  female
# 4              5         0       3           0          NaN    male
# 5              6         0       3           0          NaN    male
# 6              7         0       1           0          E46    male
# 7              8         0       3           0          NaN    male
# 8              9         1       3           1          NaN  female
# 9             10         1       2           1          NaN  female
# 10            11         1       3           1           G6  female
# 11            12         1       1           1         C103  female
# 12            13         0       3           0          NaN    male
# ...

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
bananas = 3
days = 5
like = "shit"
"Eric ate {0} bananas for {1} days like {2}.".format(bananas, days, like)
# Out:
# 'Eric ate 3 bananas for 5 days like shit.'

# %%
f"Eric ate {bananas} bananas for {days} days like {like}."
# Out:
# 'Eric ate 3 bananas for 5 days like shit.'

# %%
model_a = 0.123456789
model_b = 0.987654321

f"[Accuracy] Model A = {model_a:.5}, Model B = {model_b:.3}"
# Out:
# '[Accuracy] Model A = 0.12346, Model B = 0.988'

# %%
## 문자열

# %%
message = "Hello World"
message
# Out:
# 'Hello World'

# %%
print (message[0])
print (message[-1])
print (message[0:4])
print ("H" in message)
print ("h" in message)
# Out:
# H
# d
# Hell
# True
# False

# %%
message.lower()
message.upper()
# Out:
# 'HELLO WORLD'

# %%
##리스트

# %%
odd = [1, 3, 5, 7, 9]

# %%
odd
# Out:
# [1, 3, 5, 7, 9]

# %%
print(odd[0])
print(odd[-1])
print(odd[0:3])
print(1 in odd)
odd.append(11)
odd
# Out:
# 1
# 9
# [1, 3, 5]
# True
# [1, 3, 5, 7, 9, 11]

# %%
odd.reverse()
odd
# Out:
# [11, 9, 7, 5, 3, 1]

# %%
age = 10

if age < 5:
    print("아이")
elif age < 18:
    print("학생")
else:
    print("어른")
# Out:
# 학생

# %%
basket = ['apple', 'banana', 'chicken', 'pineapple', 'cherry']
print(basket)

for product in basket:
    print(product)
# Out:
# ['apple', 'banana', 'chicken', 'pineapple', 'cherry']
# apple
# banana
# chicken
# pineapple
# cherry

# %%
for i in range(1,10):
    if i == 2:
        print("beep!")
        continue
        
    if i == 5:
        print("bang!")
        break
        
    print(i)
# Out:
# 1
# beep!
# 3
# 4
# bang!

# %%
double_list = []

for i in range(1, 11):
    if i == 5:
        continue
    if i == 8:
        break
        
    double = i * 2
    double_list.append(double)
    
double_list
# Out:
# [2, 4, 6, 8, 12, 14]

# %% [markdown]
# ## 함수

# %%
def multiply(a,b):
    c = a * b
    return c

print(multiply(2, 3))
print(multiply(3, 4))
# Out:
# 6
# 12

# %%
def sign(n):
    if n > 0:
        return '양수'
    elif n < 0:
        return '음수'
    else:
        return '0'
    
print(sign(0))
print(sign(1))
print(sign(-1))
# Out:
# 0
# 양수
# 음수

# %%
pwd
# Out:
# 'C:\\Users\\elee0'

# %%
pwd
# Out:
# 'C:\\Users\\elee0'
